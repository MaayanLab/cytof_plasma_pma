# %% [markdown]
# # CyTOF Downsampled View

# %%
from clustergrammer_widget import *

# %%
net = Network()
net.load_file('cytof_data/CyTOF_Plasma_kmeans_downsample.txt')
net.make_clust()

# %%
clustergrammer_widget(network=net.widget())

# %% [markdown]
# We see that measurements cluster largely according to their marker-type: phospho- and surface-marker. We also see that our cell-clusters form five large scale clusters.
#
# ## Natural Killer Cell Cluster
# The left cluster of cells has high levels of *CD16* and *CD56* surface markers, which are usually expressed in .atural killer cells.
#
# ## T Cell Cluster
# Teh right cluster appears to be broadly classified as T-cells due to high CD4 and CD3 levels.
